# %%
import pandas as pd
import numpy as np

np.random.seed(24)
df = pd.DataFrame({'A': np.linspace(1, 10, 10)})
df = pd.concat([df, pd.DataFrame(np.random.randn(10, 4), columns=list('BCDE'))],
               axis=1)
df.iloc[0, 2] = np.nan

# %%
def color_negative_red(val):
    """
    Takes a scalar and returns a string with
    the css property `'color: red'` for negative
    strings, black otherwise.
    """
    color = 'red' if val < 0 else 'black'
    return 'color: %s' % color

# %%
s = df.style.applymap(color_negative_red)

# %%
s
# Out:
#         <style  type="text/css" >
#
#
#             #T_b4ae9c82_30d5_11e7_b662_acde48001122row0_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_b4ae9c82_30d5_11e7_b662_acde48001122row0_col1 {
#
#                 color:  black;
#
#             }
#
#             #T_b4ae9c82_30d5_11e7_b662_acde48001122row0_col2 {
#
#                 color:  black;
#
#             }
#
#             #T_b4ae9c82_30d5_11e7_b662_acde48001122row0_col3 {
#
#                 color:  red;
#
#             }
#
#             #T_b4ae9c82_30d5_11e7_b662_acde48001122row0_col4 {
#
#                 color:  red;
#
#             }
#
#             #T_b4ae9c82_30d5_11e7_b662_acde48001122row1_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_b4ae9c82_30d5_11e7_b662_acde48001122row1_col1 {
#
#                 color:  red;
#
#             }
#
#             #T_b4ae9c82_30d5_11e7_b662_acde48001122row1_col2 {
#
#                 color:  red;
#
#             }
#
#             #T_b4ae9c82_30d5_11e7_b662_acde48001122row1_col3 {
#
#                 color:  black;
#
#             }
#
#             #T_b4ae9c82_30d5_11e7_b662_acde48001122row1_col4 {
#
#                 color:  black;
#
#             }
#
#             #T_b4ae9c82_30d5_11e7_b662_acde48001122row2_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_b4ae9c82_30d5_11e7_b662_acde48001122row2_col1 {
#
#                 color:  red;
#
#             }
#
#             #T_b4ae9c82_30d5_11e7_b662_acde48001122row2_col2 {
#
#                 color:  black;
#
#             }
#
#             #T_b4ae9c82_30d5_11e7_b662_acde48001122row2_col3 {
#
#                 color:  black;
#
#             }
#
#             #T_b4ae9c82_30d5_11e7_b662_acde48001122row2_col4 {
#
#                 color:  black;
#
#             }
#
#             #T_b4ae9c82_30d5_11e7_b662_acde48001122row3_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_b4ae9c82_30d5_11e7_b662_acde48001122row3_col1 {
#
#                 color:  black;
#
#             }
#
#             #T_b4ae9c82_30d5_11e7_b662_acde48001122row3_col2 {
#
#                 color:  black;
#
#             }
#
#             #T_b4ae9c82_30d5_11e7_b662_acde48001122row3_col3 {
#
#                 color:  red;
#
#             }
#
#             #T_b4ae9c82_30d5_11e7_b662_acde48001122row3_col4 {
#
#                 color:  black;
#
#             }
#
#             #T_b4ae9c82_30d5_11e7_b662_acde48001122row4_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_b4ae9c82_30d5_11e7_b662_acde48001122row4_col1 {
#
#                 color:  black;
#
#             }
#
#             #T_b4ae9c82_30d5_11e7_b662_acde48001122row4_col2 {
#
#                 color:  black;
#
#             }
#
#             #T_b4ae9c82_30d5_11e7_b662_acde48001122row4_col3 {
#
#                 color:  black;
#
#             }
#
#             #T_b4ae9c82_30d5_11e7_b662_acde48001122row4_col4 {
#
#                 color:  black;
#
#             }
#
#             #T_b4ae9c82_30d5_11e7_b662_acde48001122row5_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_b4ae9c82_30d5_11e7_b662_acde48001122row5_col1 {
#
#                 color:  red;
#
#             }
#
#             #T_b4ae9c82_30d5_11e7_b662_acde48001122row5_col2 {
#
#                 color:  black;
#
#             }
#
#             #T_b4ae9c82_30d5_11e7_b662_acde48001122row5_col3 {
#
#                 color:  black;
#
#             }
#
#             #T_b4ae9c82_30d5_11e7_b662_acde48001122row5_col4 {
#
#                 color:  red;
#
#             }
#
#             #T_b4ae9c82_30d5_11e7_b662_acde48001122row6_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_b4ae9c82_30d5_11e7_b662_acde48001122row6_col1 {
#
#                 color:  black;
#
#             }
#
#             #T_b4ae9c82_30d5_11e7_b662_acde48001122row6_col2 {
#
#                 color:  black;
#
#             }
#
#             #T_b4ae9c82_30d5_11e7_b662_acde48001122row6_col3 {
#
#                 color:  red;
#
#             }
#
#             #T_b4ae9c82_30d5_11e7_b662_acde48001122row6_col4 {
#
#                 color:  black;
#
#             }
#
#             #T_b4ae9c82_30d5_11e7_b662_acde48001122row7_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_b4ae9c82_30d5_11e7_b662_acde48001122row7_col1 {
#
#                 color:  black;
#
#             }
#
#             #T_b4ae9c82_30d5_11e7_b662_acde48001122row7_col2 {
#
#                 color:  black;
#
#             }
#
#             #T_b4ae9c82_30d5_11e7_b662_acde48001122row7_col3 {
#
#                 color:  red;
#
#             }
#
#             #T_b4ae9c82_30d5_11e7_b662_acde48001122row7_col4 {
#
#                 color:  black;
#
#             }
#
#             #T_b4ae9c82_30d5_11e7_b662_acde48001122row8_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_b4ae9c82_30d5_11e7_b662_acde48001122row8_col1 {
#
#                 color:  black;
#
#             }
#
#             #T_b4ae9c82_30d5_11e7_b662_acde48001122row8_col2 {
#
#                 color:  red;
#
#             }
#
#             #T_b4ae9c82_30d5_11e7_b662_acde48001122row8_col3 {
#
#                 color:  black;
#
#             }
#
#             #T_b4ae9c82_30d5_11e7_b662_acde48001122row8_col4 {
#
#                 color:  red;
#
#             }
#
#             #T_b4ae9c82_30d5_11e7_b662_acde48001122row9_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_b4ae9c82_30d5_11e7_b662_acde48001122row9_col1 {
#
#                 color:  red;
#
#             }
#
#             #T_b4ae9c82_30d5_11e7_b662_acde48001122row9_col2 {
#
#                 color:  black;
#
#             }
#
#             #T_b4ae9c82_30d5_11e7_b662_acde48001122row9_col3 {
#
#                 color:  red;
#
#             }
#
#             #T_b4ae9c82_30d5_11e7_b662_acde48001122row9_col4 {
#
#                 color:  black;
#
#             }
#
#         </style>
#
#         <table id="T_b4ae9c82_30d5_11e7_b662_acde48001122" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   A
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   B
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   C
#
#
#
#                 <th class="col_heading level0 col3" colspan=1>
#                   D

# %%
def highlight_max(s):
    '''
    highlight the maximum in a Series yellow.
    '''
    is_max = s == s.max()
    return ['background-color: yellow' if v else '' for v in is_max]

# %%
df.style.apply(highlight_max)
# Out:
#         <style  type="text/css" >
#
#
#             #T_c088a194_30d5_11e7_8710_acde48001122row2_col4 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_c088a194_30d5_11e7_8710_acde48001122row6_col2 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_c088a194_30d5_11e7_8710_acde48001122row8_col1 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_c088a194_30d5_11e7_8710_acde48001122row8_col3 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_c088a194_30d5_11e7_8710_acde48001122row9_col0 {
#
#                 background-color:  yellow;
#
#             }
#
#         </style>
#
#         <table id="T_c088a194_30d5_11e7_8710_acde48001122" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   A
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   B
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   C
#
#
#
#                 <th class="col_heading level0 col3" colspan=1>
#                   D
#
#
#
#                 <th class="col_heading level0 col4" colspan=1>
#                   E
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_c088a194_30d5_11e7_8710_acde48001122"
#                  class="row_heading level0 row0" rowspan=1>
#                     0
#
#
#
#                 <td id="T_c088a194_30d5_11e7_8710_acde48001122row0_col0"
#                  class="data row0 col0" >
#                     1
#
#
#
#                 <td id="T_c088a194_30d5_11e7_8710_acde48001122row0_col1"
#                  class="data row0 col1" >
#                     1.32921
#
#
#
#                 <td id="T_c088a194_30d5_11e7_8710_acde48001122row0_col2"
#                  class="data row0 col2" >
#                     nan
#
#
#
#                 <td id="T_c088a194_30d5_11e7_8710_acde48001122row0_col3"
#                  class="data row0 col3" >
#                     -0.31628
#
#
#
#                 <td id="T_c088a194_30d5_11e7_8710_acde48001122row0_col4"
#                  class="data row0 col4" >
#                     -0.99081
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_c088a194_30d5_11e7_8710_acde48001122"
#                  class="row_heading level0 row1" rowspan=1>
#                     1
#
#
#
#                 <td id="T_c088a194_30d5_11e7_8710_acde48001122row1_col0"
#                  class="data row1 col0" >
#                     2
#
#
#
#                 <td id="T_c088a194_30d5_11e7_8710_acde48001122row1_col1"
#                  class="data row1 col1" >
#                     -1.07082
#
#
#
#                 <td id="T_c088a194_30d5_11e7_8710_acde48001122row1_col2"
#                  class="data row1 col2" >
#                     -1.43871
#
#
#
#                 <td id="T_c088a194_30d5_11e7_8710_acde48001122row1_col3"
#                  class="data row1 col3" >
#                     0.564417
#
#
#
#                 <td id="T_c088a194_30d5_11e7_8710_acde48001122row1_col4"
#                  class="data row1 col4" >
#                     0.295722
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_c088a194_30d5_11e7_8710_acde48001122"
#                  class="row_heading level0 row2" rowspan=1>
#                     2
#
#
#
#                 <td id="T_c088a194_30d5_11e7_8710_acde48001122row2_col0"
#                  class="data row2 col0" >
#                     3
#
#
#
#                 <td id="T_c088a194_30d5_11e7_8710_acde48001122row2_col1"
#                  class="data row2 col1" >
#                     -1.6264
#
#
#
#                 <td id="T_c088a194_30d5_11e7_8710_acde48001122row2_col2"
#                  class="data row2 col2" >
#                     0.219565
#
#
#
#                 <td id="T_c088a194_30d5_11e7_8710_acde48001122row2_col3"
#                  class="data row2 col3" >
#                     0.678805
#
#
#
#                 <td id="T_c088a194_30d5_11e7_8710_acde48001122row2_col4"
#                  class="data row2 col4" >
#                     1.88927
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_c088a194_30d5_11e7_8710_acde48001122"
#                  class="row_heading level0 row3" rowspan=1>
#                     3
#
#
#
#                 <td id="T_c088a194_30d5_11e7_8710_acde48001122row3_col0"
#                  class="data row3 col0" >
#                     4
#
#
#
#                 <td id="T_c088a194_30d5_11e7_8710_acde48001122row3_col1"
#                  class="data row3 col1" >
#                     0.961538
#
#
#
#                 <td id="T_c088a194_30d5_11e7_8710_acde48001122row3_col2"
#                  class="data row3 col2" >
#                     0.104011
#
#
#
#                 <td id="T_c088a194_30d5_11e7_8710_acde48001122row3_col3"
#                  class="data row3 col3" >
#                     -0.481165
#
#
#
#                 <td id="T_c088a194_30d5_11e7_8710_acde48001122row3_col4"
#                  class="data row3 col4" >
#                     0.850229
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_c088a194_30d5_11e7_8710_acde48001122"
#                  class="row_heading level0 row4" rowspan=1>
#                     4
#
#
#
#                 <td id="T_c088a194_30d5_11e7_8710_acde48001122row4_col0"
#                  class="data row4 col0" >
#                     5
#
#
#
#                 <td id="T_c088a194_30d5_11e7_8710_acde48001122row4_col1"
#                  class="data row4 col1" >
#                     1.45342
#
#
#
#                 <td id="T_c088a194_30d5_11e7_8710_acde48001122row4_col2"
#                  class="data row4 col2" >
#                     1.05774
#
#
#
#                 <td id="T_c088a194_30d5_11e7_8710_acde48001122row4_col3"
#                  class="data row4 col3" >
#                     0.165562
#
#
#
#                 <td id="T_c088a194_30d5_11e7_8710_acde48001122row4_col4"
#                  class="data row4 col4" >
#                     0.515018
#
#
#             </tr>
#
#             <tr

# %%
df.style.\
    applymap(color_negative_red).\
    apply(highlight_max)
# Out:
#         <style  type="text/css" >
#
#
#             #T_c66ef214_30d5_11e7_bf1e_acde48001122row0_col0 {
#
#                 color:  black;
#
#                 : ;
#
#             }
#
#             #T_c66ef214_30d5_11e7_bf1e_acde48001122row0_col1 {
#
#                 color:  black;
#
#                 : ;
#
#             }
#
#             #T_c66ef214_30d5_11e7_bf1e_acde48001122row0_col2 {
#
#                 color:  black;
#
#                 : ;
#
#             }
#
#             #T_c66ef214_30d5_11e7_bf1e_acde48001122row0_col3 {
#
#                 color:  red;
#
#                 : ;
#
#             }
#
#             #T_c66ef214_30d5_11e7_bf1e_acde48001122row0_col4 {
#
#                 color:  red;
#
#                 : ;
#
#             }
#
#             #T_c66ef214_30d5_11e7_bf1e_acde48001122row1_col0 {
#
#                 color:  black;
#
#                 : ;
#
#             }
#
#             #T_c66ef214_30d5_11e7_bf1e_acde48001122row1_col1 {
#
#                 color:  red;
#
#                 : ;
#
#             }
#
#             #T_c66ef214_30d5_11e7_bf1e_acde48001122row1_col2 {
#
#                 color:  red;
#
#                 : ;
#
#             }
#
#             #T_c66ef214_30d5_11e7_bf1e_acde48001122row1_col3 {
#
#                 color:  black;
#
#                 : ;
#
#             }
#
#             #T_c66ef214_30d5_11e7_bf1e_acde48001122row1_col4 {
#
#                 color:  black;
#
#                 : ;
#
#             }
#
#             #T_c66ef214_30d5_11e7_bf1e_acde48001122row2_col0 {
#
#                 color:  black;
#
#                 : ;
#
#             }
#
#             #T_c66ef214_30d5_11e7_bf1e_acde48001122row2_col1 {
#
#                 color:  red;
#
#                 : ;
#
#             }
#
#             #T_c66ef214_30d5_11e7_bf1e_acde48001122row2_col2 {
#
#                 color:  black;
#
#                 : ;
#
#             }
#
#             #T_c66ef214_30d5_11e7_bf1e_acde48001122row2_col3 {
#
#                 color:  black;
#
#                 : ;
#
#             }
#
#             #T_c66ef214_30d5_11e7_bf1e_acde48001122row2_col4 {
#
#                 color:  black;
#
#                 background-color:  yellow;
#
#             }
#
#             #T_c66ef214_30d5_11e7_bf1e_acde48001122row3_col0 {
#
#                 color:  black;
#
#                 : ;
#
#             }
#
#             #T_c66ef214_30d5_11e7_bf1e_acde48001122row3_col1 {
#
#                 color:  black;
#
#                 : ;
#
#             }
#
#             #T_c66ef214_30d5_11e7_bf1e_acde48001122row3_col2 {
#
#                 color:  black;
#
#                 : ;
#
#             }
#
#             #T_c66ef214_30d5_11e7_bf1e_acde48001122row3_col3 {
#
#                 color:  red;
#
#                 : ;
#
#             }
#
#             #T_c66ef214_30d5_11e7_bf1e_acde48001122row3_col4 {
#
#                 color:  black;
#
#                 : ;
#
#             }
#
#             #T_c66ef214_30d5_11e7_bf1e_acde48001122row4_col0 {
#
#                 color:  black;
#
#                 : ;
#
#             }
#
#             #T_c66ef214_30d5_11e7_bf1e_acde48001122row4_col1 {
#
#                 color:  black;
#
#                 : ;
#
#             }
#
#             #T_c66ef214_30d5_11e7_bf1e_acde48001122row4_col2 {
#
#                 color:  black;
#
#                 : ;
#
#             }
#
#             #T_c66ef214_30d5_11e7_bf1e_acde48001122row4_col3 {
#
#                 color:  black;
#
#                 : ;
#
#             }
#
#             #T_c66ef214_30d5_11e7_bf1e_acde48001122row4_col4 {
#
#                 color:  black;
#
#                 : ;
#
#             }
#
#             #T_c66ef214_30d5_11e7_bf1e_acde48001122row5_col0 {
#
#                 color:  black;
#
#                 : ;
#
#             }
#
#             #T_c66ef214_30d5_11e7_bf1e_acde48001122row5_col1 {
#
#                 color:  red;
#
#                 : ;
#
#             }
#
#             #T_c66ef214_30d5_11e7_bf1e_acde48001122row5_col2 {
#
#                 color:  black;
#
#                 : ;
#
#             }
#
#             #T_c66ef214_30d5_11e7_bf1e_acde48001122row5_col3 {
#
#                 color:  black;
#
#                 : ;
#
#             }
#
#             #T_c66ef214_30d5_11e7_bf1e_acde48001122row5_col4 {
#
#                 color:  red;
#
#                 : ;
#
#             }
#
#             #T_c66ef214_30d5_11e7_bf1e_acde48001122row6_col0 {
#
#                 color:  black;
#
#                 : ;
#
#             }
#
#             #T_c66ef214_30d5_11e7_bf1e_acde48001122row6_col1 {
#
#                 color:  black;
#
#                 : ;
#
#             }
#
#             #T_c66ef214_30d5_11e7_bf1e_acde48001122row6_col2 {
#
#                 color:  black;
#
#                 background-color:  yellow;
#
#             }
#
#             #T_c66ef214_30d5_11e7_bf1e_acde48001122row6_col3 {
#
#                 color:  red;
#
#                 : ;
#
#             }
#
#             #T_c66ef214_30d5_11e7_bf1e_acde48001122row6_col4 {
#
#                 color:  black;
#
#                 : ;
#
#             }
#
#             #T_c66ef214_30d5_11e7_bf1e_acde48001122row7_col0 {
#
#                 color:  black;
#
#                 : ;
#
#             }
#
#             #T_c66ef214_30d5_11e7_bf1e_acde48001122row7_col1 {
#
#                 color:  black;
#
#                 : ;
#
#             }
#
#             #T_c66ef214_30d5_11e7_bf1e_acde48001122row7_col2 {
#
#                 color:  black;
#
#                 : ;
#
#             }
#
#             #T_c66ef214_30d5_11e7_bf1e_acde48001122row7_col3 {
#
#                 color:  red;
#
#                 : ;
#
#             }
#
#             #T_c66ef214_30d5_11e7_bf1e_acde48001122row7_col4 {
#
#                 color:  black;
#
#                 : ;
#
#             }
#
#             #T_c66ef214_30d5_11e7_bf1e_acde48001122row8_col0 {
#
#                 color:  black;
#
#                 : ;
#
#             }
#
#             #T_c66ef214_30d5_11e7_bf1e_acde48001122row8_col1 {
#
#                 color:  black;
#
#                 background-color:  yellow;
#
#             }
#
#             #T_c66ef214_30d5_11e7_bf1e_acde48001122row8_col2 {
#
#                 color:  red;
#
#                 : ;
#
#             }
#
#             #T_c66ef214_30d5_11e7_bf1e_acde48001122row8_col3 {
#
#                 color:  black;
#
#                 background-color:  yellow;
#
#             }
#
#             #T_c66ef214_30d5_11e7_bf1e_acde48001122row8_col4 {
#
#                 color:  red;
